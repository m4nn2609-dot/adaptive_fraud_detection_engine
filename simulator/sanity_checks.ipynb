# %%
from base_gen import df,df_transactions,all_transactions

# %%
df.shape
# Out:
# (2500, 5)

# %%
df.isnull().sum()
# Out:
# user_country            0
# creation_date           0
# user_device             0
# user_transaction_min    0
# user_transaction_max    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['user_country', 'creation_date', 'user_device', 'user_transaction_min',
#        'user_transaction_max'],
#       dtype='str')

# %%
df.head(6)
# Out:
#                                           user_country creation_date  \
# a6be04d7-9e42-40f3-a765-cae7c582ae9b              Chad    1989-09-06
# 377669e1-e337-43bb-95df-1df1bdc7fea3            Bhutan    1989-11-17
# ae34615a-0b2c-474c-8e87-c4a0cd28ca0c            Brazil    2011-12-17
# 7c91ded9-385d-4ad6-a489-5b8b7969b65b             Nepal    2013-09-09
# 04e52c19-91b7-43b2-8b56-1191964a2079  Marshall Islands    1995-10-26
# 0e13cd38-8e8a-4a34-b760-2ae39c6aaf06             Congo    1971-03-22
#
#                                            user_device  user_transaction_min  \
# a6be04d7-9e42-40f3-a765-cae7c582ae9b           android                    84
# 377669e1-e337-43bb-95df-1df1bdc7fea3            iphone                   117
# ae34615a-0b2c-474c-8e87-c4a0cd28ca0c  desktop(windows)                    73
# 7c91ded9-385d-4ad6-a489-5b8b7969b65b           android                   194
# 04e52c19-91b7-43b2-8b56-1191964a2079      desktop(mac)                   183
# ...
